# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('dataset_Facebook.csv',sep=";")

# %%
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
#data subset

subset_1 = df[['Type','Lifetime Post reach by people who like your Page']]

# %%
subset_1
# Out:
#        Type  Lifetime Post reach by people who like your Page
# 0     Photo                                              1640
# 1    Status                                              6112
# 2     Photo                                              1503
# 3     Photo                                             32048
# 4     Photo                                              3200
# ..      ...                                               ...
# 495   Photo                                              2876
# 496   Photo                                              2104
# 497   Photo                                              2388
# 498   Photo                                              2452
# 499   Photo                                              2200
#
# [500 rows x 2 columns]

# %%
subset_2  = df[['Type','Post Month', 'comment']]
subset_2
# Out:
#        Type  Post Month  comment
# 0     Photo          12        4
# 1    Status          12        5
# 2     Photo          12        0
# 3     Photo          12       58
# 4     Photo          12       19
# ..      ...         ...      ...
# 495   Photo           1        5
# 496   Photo           1        0
# 497   Photo           1        4
# 498   Photo           1        7
# 499   Photo           1        0
#
# [500 rows x 3 columns]

# %%
merged_subset = pd.concat([subset_1,subset_2] , axis =1)
merged_subset
# Out:
#        Type  Lifetime Post reach by people who like your Page    Type  \
# 0     Photo                                              1640   Photo
# 1    Status                                              6112  Status
# 2     Photo                                              1503   Photo
# 3     Photo                                             32048   Photo
# 4     Photo                                              3200   Photo
# ..      ...                                               ...     ...
# 495   Photo                                              2876   Photo
# 496   Photo                                              2104   Photo
# 497   Photo                                              2388   Photo
# 498   Photo                                              2452   Photo
# 499   Photo                                              2200   Photo
#
#      Post Month  comment
# 0            12        4
# 1            12        5
# 2            12        0
# ...

# %%
soreted = df.sort_values(by='Lifetime Post Total Reach' , ascending = False)
soreted
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 244            130791  Photo         2           7             3          5
# 464             92079  Photo         1           2             6         13
# 463             92186  Photo         3           2             7          2
# 277            126424  Video         1           6             2         13
# 380            111620  Photo         1           4             7         14
# ..                ...    ...       ...         ...           ...        ...
# 123            136393  Photo         1          10             7          7
# 120            136393  Photo         1          10             7          9
# 432            100732  Photo         1           3             6         17
# 426            100732  Photo         1           3             7         18
# 422            102112  Photo         1           3             1         19
#
# ...

# %%
transposed_df = merged_subset.transpose()
transposed_df
# Out:
#                                                     0       1      2      3    \
# Type                                              Photo  Status  Photo  Photo
# Lifetime Post reach by people who like your Page   1640    6112   1503  32048
# Type                                              Photo  Status  Photo  Photo
# Post Month                                           12      12     12     12
# comment                                               4       5      0     58
#
#                                                     4       5      6      7    \
# Type                                              Photo  Status  Photo  Photo
# Lifetime Post reach by people who like your Page   3200    7852   9328  11056
# Type                                              Photo  Status  Photo  Photo
# Post Month                                           12      12     12     12
# comment                                              19       1      3      0
#
# ...

# %%
print(df.shape)
# Out:
# (500, 19)

# %%
# reshape 

arr = np.array(df[['Post Month', 'Post Weekday']].head(6))
reshaped = arr.reshape(3,4)
reshaped
# Out:
# array([[12,  4, 12,  3],
#        [12,  3, 12,  2],
#        [12,  2, 12,  1]])

# %%
arrr = np.array(df[['Post Month','Post Weekday']].head(6))

reshaped_daata = arrr.reshape(4,3)
reshaped_daata
# Out:
# array([[12,  4, 12],
#        [ 3, 12,  3],
#        [12,  2, 12],
#        [ 2, 12,  1]])
